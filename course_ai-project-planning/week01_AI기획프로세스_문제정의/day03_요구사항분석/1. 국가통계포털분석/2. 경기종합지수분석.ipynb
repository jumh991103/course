# %% [markdown]
# # [국가통계포털 KOSIS 💰 경기종합지수 분석하기](https://www.youtube.com/watch?v=c62S-WZtVJ4)

# %% [markdown]
# ## [경기종합지수 통계 다운로드](https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1C8015&conn_path=I2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
df = pd.read_csv("./data/kosis-economic.csv", index_col="시점")
df.head()
# Out:
#          선행종합지수(2020=100)  선행종합지수 전월비(%)  재고순환지표(전월차)(%p)  경제심리지수(전월차)(p)  \
# 시점
# 2017.01              89.7            0.6              3.6             0.0
# 2017.02              90.1            0.4              1.6             0.6
# 2017.03              90.5            0.4              0.4             2.2
# 2017.04              91.0            0.6             -1.8             1.3
# 2017.05              91.2            0.2             -3.1             1.0
#
#          기계류내수출하지수(선박제외)(전월비)(%)  건설수주액(전월비)(%)  수출입물가비율(전월비)(%)  코스피(전월비)(%)  \
# 시점
# 2017.01                      2.2          -11.9             -0.2          0.4
# 2017.02                      0.6           19.3             -0.4          1.7
# 2017.03                      0.8           -6.8              0.1          1.9
# 2017.04                     -0.3           12.3              0.6          1.6
# 2017.05                      0.8          -16.4              0.5          3.4
#
#          장단기금리차(전월차)(%p)  선행지수 순환변동치  ...  비농림어업취업자수(전월비)(%)  동행지수 순환변동치  \
# 시점                                    ...
# 2017.01             0.13       100.4  ...                0.1       100.7
# 2017.02             0.04       100.7  ...                0.1       100.7
# 2017.03             0.01       100.9  ...                0.1       100.9
# 2017.04             0.02       101.1  ...                0.1       101.0
# 2017.05             0.02       101.2  ...                0.1       101.1
#
#          〔순환변동치 전월차〕(p).1  후행종합지수(2020=100)  후행종합지수 전월비(%)  생산자제품재고지수(전월비)(%)  \
# 시점
# 2017.01               0.4              90.8            0.2               -0.9
# 2017.02               0.0              91.0            0.2               -0.6
# 2017.03               0.2              91.3            0.3                0.7
# 2017.04               0.1              91.6            0.3                1.0
# 2017.05               0.1              91.8            0.2                1.5
#
#          소비자물가지수변화율(서비스)(전월차)(%p)  소비재수입액(전월비)(%)  취업자수(전월비)(%)  \
# 시점
# 2017.01                       0.1             0.2           0.1
# 2017.02                       0.0             0.5           0.1
# 2017.03                       0.0             1.8           0.1
# 2017.04                       0.0             1.3           0.1
# 2017.05                      -0.1            -0.4           0.0
#
#          CP유통수익률(전월차)(%p)
# 시점
# 2017.01               0.1
# 2017.02               0.0
# 2017.03               0.0
# 2017.04               0.0
# 2017.05               0.0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 95 entries, 2017.01 to 2024.11 p)
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   선행종합지수(2020=100)          95 non-null     float64
#  1   선행종합지수 전월비(%)             95 non-null     float64
#  2   재고순환지표(전월차)(%p)           95 non-null     float64
#  3   경제심리지수(전월차)(p)            95 non-null     float64
#  4   기계류내수출하지수(선박제외)(전월비)(%)   95 non-null     float64
#  5   건설수주액(전월비)(%)             95 non-null     float64
#  6   수출입물가비율(전월비)(%)           95 non-null     float64
#  7   코스피(전월비)(%)               95 non-null     float64
#  8   장단기금리차(전월차)(%p)           95 non-null     float64
#  9   선행지수 순환변동치                95 non-null     float64
#  10  〔순환변동치 전월차〕(p)            95 non-null     float64
#  11  선행지수 전년동월비(%)             95 non-null     float64
#  12  〔전년동월비 전월차〕(%p)           95 non-null     float64
#  13  동행종합지수(2020=100)          95 non-null     float64
#  14  동행종합지수 전월비(%)             95 non-null     float64
#  15  광공업생산지수(전월비)(%)           95 non-null     float64
#  16  서비스업생산지수(도소매업제외)(전월비)(%)  95 non-null     float64
#  17  건설기성액(전월비)(%)             95 non-null     float64
#  18  소매판매액지수(전월비)(%)           95 non-null     float64
#  19  내수출하지수(전월비)(%)            95 non-null     float64
#  20  수입액(전월비)(%)               95 non-null     float64
#  21  비농림어업취업자수(전월비)(%)         95 non-null     float64
#  22  동행지수 순환변동치                95 non-null     float64
#  23  〔순환변동치 전월차〕(p).1          95 non-null     float64
#  24  후행종합지수(2020=100)          95 non-null     float64
#  25  후행종합지수 전월비(%)             95 non-null     float64
#  26  생산자제품재고지수(전월비)(%)         95 non-null     float64
#  27  소비자물가지수변화율(서비스)(전월차)(%p)  95 non-null     float64
#  28  소비재수입액(전월비)(%)            95 non-null     float64
#  29  취업자수(전월비)(%)              95 non-null     float64
#  30  CP유통수익률(전월차)(%p)          95 non-null     float64
# dtypes: float64(31)
# memory usage: 23.8+ KB

# %% [markdown]
# ## 기초 통계 분석

# %%
# 기초 통계 분석
df.describe()  # 데이터프레임의 기초 통계 정보 출력
# Out:
#        선행종합지수(2020=100)  선행종합지수 전월비(%)  재고순환지표(전월차)(%p)  경제심리지수(전월차)(p)  \
# count         95.000000      95.000000        95.000000       95.000000
# mean         102.796842       0.288421        -0.014737       -0.025263
# std            8.156520       0.242708         2.420039        2.448880
# min           89.700000      -0.300000        -6.100000      -12.100000
# 25%           94.800000       0.100000        -1.600000       -0.900000
# 50%          103.200000       0.300000         0.100000        0.000000
# 75%          109.300000       0.400000         1.500000        0.950000
# max          117.300000       0.900000         4.700000        6.400000
#
#        기계류내수출하지수(선박제외)(전월비)(%)  건설수주액(전월비)(%)  수출입물가비율(전월비)(%)  코스피(전월비)(%)  \
# count                95.000000      95.000000        95.000000    95.000000
# mean                 -0.015789       0.660000        -0.113684     0.285263
# std                   1.827992       9.659098         0.800081     2.667853
# min                  -4.100000     -23.100000        -2.200000    -5.700000
# 25%                  -1.400000      -4.000000        -0.600000    -1.800000
# 50%                  -0.200000       0.900000        -0.100000     0.400000
# 75%                   0.900000       5.800000         0.350000     1.900000
# max                   4.400000      25.000000         3.400000     9.600000
#
#        장단기금리차(전월차)(%p)  선행지수 순환변동치  ...  비농림어업취업자수(전월비)(%)  동행지수 순환변동치  \
# count        95.000000   95.000000  ...          95.000000   95.000000
# mean         -0.009684  100.371579  ...           0.072632   99.792632
# std           0.116733    1.081436  ...           0.265154    1.204887
# min          -0.390000   98.500000  ...          -1.300000   96.400000
# 25%          -0.075000   99.500000  ...           0.000000   99.400000
# 50%           0.020000  100.400000  ...           0.100000   99.900000
# 75%           0.070000  101.200000  ...           0.200000  100.750000
# max           0.250000  102.800000  ...           0.800000  101.400000
#
#        〔순환변동치 전월차〕(p).1  후행종합지수(2020=100)  후행종합지수 전월비(%)  생산자제품재고지수(전월비)(%)  \
# count         95.000000         95.000000      95.000000          95.000000
# mean          -0.028421        103.227368       0.267368           0.251579
# std            0.344150          8.066459       0.153292           0.967434
# min           -1.200000         90.800000      -0.100000          -2.200000
# 25%           -0.100000         96.800000       0.200000          -0.350000
# 50%            0.000000        101.000000       0.200000           0.300000
# 75%            0.100000        111.850000       0.350000           0.750000
# max            0.900000        116.300000       0.600000           2.900000
#
#        소비자물가지수변화율(서비스)(전월차)(%p)  소비재수입액(전월비)(%)  취업자수(전월비)(%)  \
# count                 95.000000       95.000000     95.000000
# mean                  -0.004211        0.489474      0.076842
# std                    0.147976        1.764452      0.263952
# min                   -0.300000       -3.300000     -1.300000
# 25%                   -0.100000       -0.500000      0.000000
# 50%                    0.000000        0.600000      0.100000
# 75%                    0.100000        1.750000      0.200000
# max                    0.600000        4.400000      0.700000
#
#        CP유통수익률(전월차)(%p)
# count         95.000000
# mean           0.024211
# std            0.171176
# min           -0.500000
# 25%            0.000000
# 50%            0.000000
# 75%            0.100000
# max            0.800000
#
# [8 rows x 31 columns]

# %%
df.hist(figsize=(20, 15), bins=50);

# %%
# 일부 변수만 사용할 경우 (예: 처음 6개 변수):
selected_columns = df.iloc[:, :6]  # 데이터프레임에서 원하는 변수 선택
sns.pairplot(selected_columns)

# %% [markdown]
# ## 상관관계 분석

# %%
corr = df.corr()
corr
# Out:
#                           선행종합지수(2020=100)  선행종합지수 전월비(%)  재고순환지표(전월차)(%p)  \
# 선행종합지수(2020=100)                  1.000000       0.038942         0.061658
# 선행종합지수 전월비(%)                     0.038942       1.000000         0.586173
# 재고순환지표(전월차)(%p)                   0.061658       0.586173         1.000000
# 경제심리지수(전월차)(p)                    0.019787       0.618439         0.297901
# 기계류내수출하지수(선박제외)(전월비)(%)           0.097147       0.494491         0.275511
# 건설수주액(전월비)(%)                     0.019486       0.335830         0.005381
# 수출입물가비율(전월비)(%)                   0.097461       0.004106         0.042091
# 코스피(전월비)(%)                      -0.085708       0.597935         0.232000
# 장단기금리차(전월차)(%p)                  -0.147808       0.448839         0.041591
# 선행지수 순환변동치                       -0.006668       0.137754        -0.128938
# 〔순환변동치 전월차〕(p)                    0.034287       0.954514         0.578161
# 선행지수 전년동월비(%)                    -0.000722       0.435298        -0.014194
# 〔전년동월비 전월차〕(%p)                   0.039685       0.842134         0.640852
# 동행종합지수(2020=100)                  0.970565      -0.041663         0.080700
# 동행종합지수 전월비(%)                    -0.029029       0.365767         0.255233
# 광공업생산지수(전월비)(%)                   0.002512       0.337105         0.193521
# 서비스업생산지수(도소매업제외)(전월비)(%)          0.090038       0.318043         0.138326
# 건설기성액(전월비)(%)                    -0.107997      -0.099186        -0.021622
# 소매판매액지수(전월비)(%)                  -0.160259       0.180826         0.113477
# 내수출하지수(전월비)(%)                   -0.113161       0.244304         0.320223
# 수입액(전월비)(%)                      -0.068133      -0.002411         0.014422
# 비농림어업취업자수(전월비)(%)                 0.135721       0.285963         0.102816
# 동행지수 순환변동치                       -0.215167      -0.238573        -0.033530
# 〔순환변동치 전월차〕(p).1                 -0.059002       0.403578         0.270796
# 후행종합지수(2020=100)                  0.978667      -0.024669         0.078158
# 후행종합지수 전월비(%)                     0.127628      -0.078888        -0.213805
# 생산자제품재고지수(전월비)(%)                -0.109208      -0.553349        -0.774315
# 소비자물가지수변화율(서비스)(전월차)(%p)          0.072176       0.063794        -0.061668
# 소비재수입액(전월비)(%)                   -0.113313       0.203413         0.205278
# 취업자수(전월비)(%)                      0.086290       0.266447         0.114041
# CP유통수익률(전월차)(%p)                  0.081203      -0.264607        -0.142685
#
#                           경제심리지수(전월차)(p)  기계류내수출하지수(선박제외)(전월비)(%)  \
# 선행종합지수(2020=100)                0.019787                 0.097147
# 선행종합지수 전월비(%)                   0.618439                 0.494491
# 재고순환지표(전월차)(%p)                 0.297901                 0.275511
# 경제심리지수(전월차)(p)                  1.000000                 0.039977
# 기계류내수출하지수(선박제외)(전월비)(%)         0.039977                 1.000000
# 건설수주액(전월비)(%)                   0.117422                 0.149361
# 수출입물가비율(전월비)(%)                -0.429174                -0.001313
# 코스피(전월비)(%)                     0.658358                 0.024340
# 장단기금리차(전월차)(%p)                 0.146914                 0.178653
# 선행지수 순환변동치                      0.288670                 0.139849
# 〔순환변동치 전월차〕(p)                  0.586459                 0.510605
# 선행지수 전년동월비(%)                   0.349778                 0.223083
# 〔전년동월비 전월차〕(%p)                 0.436800                 0.432784
# 동행종합지수(2020=100)               -0.034836                 0.066199
# 동행종합지수 전월비(%)                   0.600794                 0.241662
# 광공업생산지수(전월비)(%)                 0.412389                 0.168314
# 서비스업생산지수(도소매업제외)(전월비)(%)        0.696594                 0.097122
# 건설기성액(전월비)(%)                  -0.040449                 0.085348
# 소매판매액지수(전월비)(%)                 0.182826                -0.033904
# 내수출하지수(전월비)(%)                  0.264899                 0.162032
# 수입액(전월비)(%)                    -0.167972                 0.229028
# 비농림어업취업자수(전월비)(%)               0.726678                 0.090403
# 동행지수 순환변동치                     -0.021516                -0.024300
# 〔순환변동치 전월차〕(p).1                0.606803                 0.247860
# 후행종합지수(2020=100)               -0.045364                 0.055741
# 후행종합지수 전월비(%)                   0.192187                 0.127981
# 생산자제품재고지수(전월비)(%)              -0.199266                -0.271799
# 소비자물가지수변화율(서비스)(전월차)(%p)        0.152066                 0.066610
# 소비재수입액(전월비)(%)                  0.122818                 0.226540
# 취업자수(전월비)(%)                    0.707935                 0.069347
# CP유통수익률(전월차)(%p)               -0.323367                 0.157626
#
#                           건설수주액(전월비)(%)  수출입물가비율(전월비)(%)  코스피(전월비)(%)  \
# 선행종합지수(2020=100)               0.019486         0.097461    -0.085708
# 선행종합지수 전월비(%)                  0.335830         0.004106     0.597935
# 재고순환지표(전월차)(%p)                0.005381         0.042091     0.232000
# 경제심리지수(전월차)(p)                 0.117422        -0.429174     0.658358
# 기계류내수출하지수(선박제외)(전월비)(%)        0.149361        -0.001313     0.024340
# 건설수주액(전월비)(%)                  1.000000        -0.157704     0.064242
# 수출입물가비율(전월비)(%)               -0.157704         1.000000    -0.186496
# 코스피(전월비)(%)                    0.064242        -0.186496     1.000000
# 장단기금리차(전월차)(%p)                0.053253        -0.103380     0.087465
# 선행지수 순환변동치                    -0.022780        -0.257179     0.113127
# 〔순환변동치 전월차〕(p)                 0.360040         0.055192     0.605209
# 선행지수 전년동월비(%)                  0.022501        -0.018238     0.406147
# 〔전년동월비 전월차〕(%p)                0.263217         0.182312     0.554766
# 동행종합지수(2020=100)              -0.004114         0.094141    -0.163964
# 동행종합지수 전월비(%)                  0.020847        -0.335589     0.206494
# 광공업생산지수(전월비)(%)                0.000032        -0.210775     0.191339
# 서비스업생산지수(도소매업제외)(전월비)(%)       0.041944        -0.476271     0.267939
# 건설기성액(전월비)(%)                 -0.157902         0.096891    -0.049399
# 소매판매액지수(전월비)(%)                0.149993        -0.248511     0.237344
# 내수출하지수(전월비)(%)                -0.069499        -0.019647     0.076245
# 수입액(전월비)(%)                   -0.059109         0.247840    -0.181762
# 비농림어업취업자수(전월비)(%)              0.138219        -0.486198     0.192220
# 동행지수 순환변동치                    -0.130210        -0.231851    -0.248115
# 〔순환변동치 전월차〕(p).1               0.039146        -0.306651     0.218297
# 후행종합지수(2020=100)               0.011989         0.134038    -0.127249
# 후행종합지수 전월비(%)                  0.007156        -0.360181    -0.148422
# 생산자제품재고지수(전월비)(%)             -0.109239        -0.099685    -0.238768
# 소비자물가지수변화율(서비스)(전월차)(%p)      -0.053857        -0.267364     0.034064
# 소비재수입액(전월비)(%)                 0.150083        -0.092642    -0.066860
# 취업자수(전월비)(%)                   0.151433        -0.499723     0.185027
# CP유통수익률(전월차)(%p)              -0.117025        -0.013091    -0.248470
#
#                           장단기금리차(전월차)(%p)  선행지수 순환변동치  ...  비농림어업취업자수(전월비)(%)  \
# 선행종합지수(2020=100)                -0.147808   -0.006668  ...           0.135721
# 선행종합지수 전월비(%)                    0.448839    0.137754  ...           0.285963
# 재고순환지표(전월차)(%p)                  0.041591   -0.128938  ...           0.102816
# 경제심리지수(전월차)(p)                   0.146914    0.288670  ...           0.726678
# 기계류내수출하지수(선박제외)(전월비)(%)          0.178653    0.139849  ...           0.090403
# 건설수주액(전월비)(%)                    0.053253   -0.022780  ...           0.138219
# 수출입물가비율(전월비)(%)                 -0.103380   -0.257179  ...          -0.486198
# 코스피(전월비)(%)                      0.087465    0.113127  ...           0.192220
# 장단기금리차(전월차)(%p)                  1.000000    0.197688  ...          -0.000749
# 선행지수 순환변동치                       0.197688    1.000000  ...           0.241005
# 〔순환변동치 전월차〕(p)                   0.412239    0.114416  ...           0.252993
# 선행지수 전년동월비(%)                    0.352708    0.798941  ...           0.093596
# 〔전년동월비 전월차〕(%p)                  0.261186   -0.277565  ...           0.141011
# 동행종합지수(2020=100)                -0.216967   -0.110150  ...           0.151504
# 동행종합지수 전월비(%)                    0.024746    0.233751  ...           0.670973
# 광공업생산지수(전월비)(%)                  0.210973    0.091756  ...           0.243172
# 서비스업생산지수(도소매업제외)(전월비)(%)         0.059511    0.241142  ...           0.782609
# 건설기성액(전월비)(%)                   -0.196599   -0.096585  ...           0.142399
# 소매판매액지수(전월비)(%)                  0.108662    0.114014  ...           0.121860
# 내수출하지수(전월비)(%)                  -0.041230    0.015032  ...           0.192286
# 수입액(전월비)(%)                     -0.062218    0.201451  ...          -0.163469
# 비농림어업취업자수(전월비)(%)               -0.000749    0.241005  ...           1.000000
# 동행지수 순환변동치                      -0.112153    0.279550  ...           0.275075
# 〔순환변동치 전월차〕(p).1                 0.041271    0.218761  ...           0.655894
# 후행종합지수(2020=100)                -0.221956   -0.172289  ...           0.102118
# 후행종합지수 전월비(%)                   -0.062436    0.358208  ...           0.480318
# 생산자제품재고지수(전월비)(%)               -0.159629    0.060901  ...           0.015100
# 소비자물가지수변화율(서비스)(전월차)(%p)         0.120788    0.432682  ...           0.170557
# 소비재수입액(전월비)(%)                   0.068194    0.174067  ...           0.091242
# 취업자수(전월비)(%)                    -0.007701    0.229109  ...           0.963658
# CP유통수익률(전월차)(%p)                -0.153185    0.107774  ...          -0.067281
#
#                           동행지수 순환변동치  〔순환변동치 전월차〕(p).1  후행종합지수(2020=100)  \
# 선행종합지수(2020=100)           -0.215167         -0.059002          0.978667
# 선행종합지수 전월비(%)              -0.238573          0.403578         -0.024669
# 재고순환지표(전월차)(%p)            -0.033530          0.270796          0.078158
# 경제심리지수(전월차)(p)             -0.021516          0.606803         -0.045364
# 기계류내수출하지수(선박제외)(전월비)(%)    -0.024300          0.247860          0.055741
# 건설수주액(전월비)(%)              -0.130210          0.039146          0.011989
# 수출입물가비율(전월비)(%)            -0.231851         -0.306651          0.134038
# 코스피(전월비)(%)                -0.248115          0.218297         -0.127249
# 장단기금리차(전월차)(%p)            -0.112153          0.041271         -0.221956
# 선행지수 순환변동치                  0.279550          0.218761         -0.172289
# 〔순환변동치 전월차〕(p)             -0.210214          0.359535         -0.013965
# 선행지수 전년동월비(%)              -0.173059          0.195374         -0.180918
# 〔전년동월비 전월차〕(%p)            -0.279933          0.203618          0.062209
# 동행종합지수(2020=100)           -0.040533         -0.065125          0.990091
# 동행종합지수 전월비(%)               0.242402          0.982995         -0.069404
# 광공업생산지수(전월비)(%)            -0.088003          0.549714         -0.037569
# 서비스업생산지수(도소매업제외)(전월비)(%)    0.276213          0.683837          0.056163
# 건설기성액(전월비)(%)               0.363225          0.344285         -0.058645
# 소매판매액지수(전월비)(%)            -0.109269          0.368496         -0.191853
# 내수출하지수(전월비)(%)              0.031229          0.672263         -0.117999
# 수입액(전월비)(%)                 0.108575          0.218764         -0.110807
# 비농림어업취업자수(전월비)(%)           0.275075          0.655894          0.102118
# 동행지수 순환변동치                  1.000000          0.202167         -0.164131
# 〔순환변동치 전월차〕(p).1            0.202167          1.000000         -0.102035
# 후행종합지수(2020=100)           -0.164131         -0.102035          1.000000
# 후행종합지수 전월비(%)               0.316625          0.435954          0.070418
# 생산자제품재고지수(전월비)(%)           0.202847         -0.008970         -0.096195
# 소비자물가지수변화율(서비스)(전월차)(%p)    0.014741          0.275459         -0.031363
# 소비재수입액(전월비)(%)              0.013424          0.413306         -0.157085
# 취업자수(전월비)(%)                0.321250          0.662555          0.054613
# CP유통수익률(전월차)(%p)            0.302102         -0.222956          0.093202
#
#                           후행종합지수 전월비(%)  생산자제품재고지수(전월비)(%)  \
# 선행종합지수(2020=100)               0.127628          -0.109208
# 선행종합지수 전월비(%)                 -0.078888          -0.553349
# 재고순환지표(전월차)(%p)               -0.213805          -0.774315
# 경제심리지수(전월차)(p)                 0.192187          -0.199266
# 기계류내수출하지수(선박제외)(전월비)(%)        0.127981          -0.271799
# 건설수주액(전월비)(%)                  0.007156          -0.109239
# 수출입물가비율(전월비)(%)               -0.360181          -0.099685
# 코스피(전월비)(%)                   -0.148422          -0.238768
# 장단기금리차(전월차)(%p)               -0.062436          -0.159629
# 선행지수 순환변동치                     0.358208           0.060901
# 〔순환변동치 전월차〕(p)                -0.158842          -0.559277
# 선행지수 전년동월비(%)                  0.088912          -0.129333
# 〔전년동월비 전월차〕(%p)               -0.308857          -0.600140
# 동행종합지수(2020=100)               0.118219          -0.085234
# 동행종합지수 전월비(%)                  0.447055           0.019302
# 광공업생산지수(전월비)(%)                0.041559          -0.012299
# 서비스업생산지수(도소매업제외)(전월비)(%)       0.482724          -0.018231
# 건설기성액(전월비)(%)                  0.157567           0.121163
# 소매판매액지수(전월비)(%)                0.084218          -0.052537
# 내수출하지수(전월비)(%)                 0.157218          -0.033888
# 수입액(전월비)(%)                    0.152014           0.082184
# 비농림어업취업자수(전월비)(%)              0.480318           0.015100
# 동행지수 순환변동치                     0.316625           0.202847
# 〔순환변동치 전월차〕(p).1               0.435954          -0.008970
# 후행종합지수(2020=100)               0.070418          -0.096195
# 후행종합지수 전월비(%)                  1.000000           0.433991
# 생산자제품재고지수(전월비)(%)              0.433991           1.000000
# 소비자물가지수변화율(서비스)(전월차)(%p)       0.641082           0.246763
# 소비재수입액(전월비)(%)                 0.382595          -0.099892
# 취업자수(전월비)(%)                   0.472791           0.017642
# CP유통수익률(전월차)(%p)               0.431799           0.114436
#
#                           소비자물가지수변화율(서비스)(전월차)(%p)  소비재수입액(전월비)(%)  \
# 선행종합지수(2020=100)                          0.072176       -0.113313
# 선행종합지수 전월비(%)                             0.063794        0.203413
# 재고순환지표(전월차)(%p)                          -0.061668        0.205278
# 경제심리지수(전월차)(p)                            0.152066        0.122818
# 기계류내수출하지수(선박제외)(전월비)(%)                   0.066610        0.226540
# 건설수주액(전월비)(%)                            -0.053857        0.150083
# 수출입물가비율(전월비)(%)                          -0.267364       -0.092642
# 코스피(전월비)(%)                               0.034064       -0.066860
# 장단기금리차(전월차)(%p)                           0.120788        0.068194
# 선행지수 순환변동치                                0.432682        0.174067
# 〔순환변동치 전월차〕(p)                           -0.023161        0.156102
# 선행지수 전년동월비(%)                             0.339736        0.151910
# 〔전년동월비 전월차〕(%p)                          -0.209122        0.008974
# 동행종합지수(2020=100)                         -0.017400       -0.149205
# 동행종합지수 전월비(%)                             0.269945        0.393357
# 광공업생산지수(전월비)(%)                           0.052272        0.156852
# 서비스업생산지수(도소매업제외)(전월비)(%)                  0.233202        0.195605
# 건설기성액(전월비)(%)                            -0.047165       -0.079540
# 소매판매액지수(전월비)(%)                           0.212939        0.345920
# 내수출하지수(전월비)(%)                            0.083565        0.344991
# 수입액(전월비)(%)                               0.243288        0.344555
# 비농림어업취업자수(전월비)(%)                         0.170557        0.091242
# 동행지수 순환변동치                                0.014741        0.013424
# 〔순환변동치 전월차〕(p).1                          0.275459        0.413306
# 후행종합지수(2020=100)                         -0.031363       -0.157085
# 후행종합지수 전월비(%)                             0.641082        0.382595
# 생산자제품재고지수(전월비)(%)                         0.246763       -0.099892
# 소비자물가지수변화율(서비스)(전월차)(%p)                  1.000000        0.124099
# 소비재수입액(전월비)(%)                            0.124099        1.000000
# 취업자수(전월비)(%)                              0.160897        0.126245
# CP유통수익률(전월차)(%p)                          0.130064       -0.083681
#
#                           취업자수(전월비)(%)  CP유통수익률(전월차)(%p)
# 선행종합지수(2020=100)              0.086290          0.081203
# 선행종합지수 전월비(%)                 0.266447         -0.264607
# 재고순환지표(전월차)(%p)               0.114041         -0.142685
# 경제심리지수(전월차)(p)                0.707935         -0.323367
# 기계류내수출하지수(선박제외)(전월비)(%)       0.069347          0.157626
# 건설수주액(전월비)(%)                 0.151433         -0.117025
# 수출입물가비율(전월비)(%)              -0.499723         -0.013091
# 코스피(전월비)(%)                   0.185027         -0.248470
# 장단기금리차(전월차)(%p)              -0.007701         -0.153185
# 선행지수 순환변동치                    0.229109          0.107774
# 〔순환변동치 전월차〕(p)                0.233611         -0.264770
# 선행지수 전년동월비(%)                 0.085765         -0.123993
# 〔전년동월비 전월차〕(%p)               0.128120         -0.214451
# 동행종합지수(2020=100)              0.113754          0.120052
# 동행종합지수 전월비(%)                 0.676089         -0.212530
# 광공업생산지수(전월비)(%)               0.259581         -0.422278
# 서비스업생산지수(도소매업제외)(전월비)(%)      0.748029         -0.027155
# 건설기성액(전월비)(%)                 0.171647          0.198332
# 소매판매액지수(전월비)(%)               0.084462         -0.168366
# 내수출하지수(전월비)(%)                0.209453         -0.209146
# 수입액(전월비)(%)                  -0.114171         -0.022998
# 비농림어업취업자수(전월비)(%)             0.963658         -0.067281
# 동행지수 순환변동치                    0.321250          0.302102
# 〔순환변동치 전월차〕(p).1              0.662555         -0.222956
# 후행종합지수(2020=100)              0.054613          0.093202
# 후행종합지수 전월비(%)                 0.472791          0.431799
# 생산자제품재고지수(전월비)(%)             0.017642          0.114436
# 소비자물가지수변화율(서비스)(전월차)(%p)      0.160897          0.130064
# 소비재수입액(전월비)(%)                0.126245         -0.083681
# 취업자수(전월비)(%)                  1.000000         -0.112249
# CP유통수익률(전월차)(%p)             -0.112249          1.000000
#
# [31 rows x 31 columns]

# %%
corr.columns
# Out:
# Index(['선행종합지수(2020=100)', '선행종합지수 전월비(%)', '재고순환지표(전월차)(%p)',
#        '경제심리지수(전월차)(p)', '기계류내수출하지수(선박제외)(전월비)(%)', '건설수주액(전월비)(%)',
#        '수출입물가비율(전월비)(%)', '코스피(전월비)(%)', '장단기금리차(전월차)(%p)', '선행지수 순환변동치',
#        '〔순환변동치 전월차〕(p)', '선행지수 전년동월비(%)', '〔전년동월비 전월차〕(%p)',
#        '동행종합지수(2020=100)', '동행종합지수 전월비(%)', '광공업생산지수(전월비)(%)',
#        '서비스업생산지수(도소매업제외)(전월비)(%)', '건설기성액(전월비)(%)', '소매판매액지수(전월비)(%)',
#        '내수출하지수(전월비)(%)', '수입액(전월비)(%)', '비농림어업취업자수(전월비)(%)', '동행지수 순환변동치',
#        '〔순환변동치 전월차〕(p).1', '후행종합지수(2020=100)', '후행종합지수 전월비(%)',
#        '생산자제품재고지수(전월비)(%)', '소비자물가지수변화율(서비스)(전월차)(%p)', '소비재수입액(전월비)(%)',
#        '취업자수(전월비)(%)', 'CP유통수익률(전월차)(%p)'],
#       dtype='str')

# %%
corr["재고순환지표(전월차)(%p)"].nsmallest(10)
# Out:
# 생산자제품재고지수(전월비)(%)          -0.774315
# 후행종합지수 전월비(%)              -0.213805
# CP유통수익률(전월차)(%p)           -0.142685
# 선행지수 순환변동치                 -0.128938
# 소비자물가지수변화율(서비스)(전월차)(%p)   -0.061668
# 동행지수 순환변동치                 -0.033530
# 건설기성액(전월비)(%)              -0.021622
# 선행지수 전년동월비(%)              -0.014194
# 건설수주액(전월비)(%)               0.005381
# 수입액(전월비)(%)                 0.014422
# Name: 재고순환지표(전월차)(%p), dtype: float64

# %%
mask = np.triu(np.ones_like(corr))

plt.figure(figsize=(15, 15))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", vmin=-1, vmax=1, mask=mask)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['선행종합지수(2020=100)', '선행종합지수 전월비(%)', '재고순환지표(전월차)(%p)',
#        '경제심리지수(전월차)(p)', '기계류내수출하지수(선박제외)(전월비)(%)', '건설수주액(전월비)(%)',
#        '수출입물가비율(전월비)(%)', '코스피(전월비)(%)', '장단기금리차(전월차)(%p)', '선행지수 순환변동치',
#        '〔순환변동치 전월차〕(p)', '선행지수 전년동월비(%)', '〔전년동월비 전월차〕(%p)',
#        '동행종합지수(2020=100)', '동행종합지수 전월비(%)', '광공업생산지수(전월비)(%)',
#        '서비스업생산지수(도소매업제외)(전월비)(%)', '건설기성액(전월비)(%)', '소매판매액지수(전월비)(%)',
#        '내수출하지수(전월비)(%)', '수입액(전월비)(%)', '비농림어업취업자수(전월비)(%)', '동행지수 순환변동치',
#        '〔순환변동치 전월차〕(p).1', '후행종합지수(2020=100)', '후행종합지수 전월비(%)',
#        '생산자제품재고지수(전월비)(%)', '소비자물가지수변화율(서비스)(전월차)(%p)', '소비재수입액(전월비)(%)',
#        '취업자수(전월비)(%)', 'CP유통수익률(전월차)(%p)'],
#       dtype='str')

# %%
sns.regplot(data=df, x='선행종합지수(2020=100)', y='후행종합지수(2020=100)')
# Out:
# <Axes: xlabel='선행종합지수(2020=100)', ylabel='후행종합지수(2020=100)'>

# %%
sns.regplot(data=df, x='생산자제품재고지수(전월비)(%)', y='재고순환지표(전월차)(%p)')
# Out:
# <Axes: xlabel='생산자제품재고지수(전월비)(%)', ylabel='재고순환지표(전월차)(%p)'>

# %%
df.describe().T.style.background_gradient()
# Out:
# <style type="text/css">
# #T_b4b27_row0_col0, #T_b4b27_row1_col0, #T_b4b27_row1_col6, #T_b4b27_row2_col0, #T_b4b27_row2_col1, #T_b4b27_row2_col5, #T_b4b27_row3_col0, #T_b4b27_row3_col1, #T_b4b27_row3_col5, #T_b4b27_row4_col0, #T_b4b27_row4_col1, #T_b4b27_row4_col5, #T_b4b27_row5_col0, #T_b4b27_row5_col3, #T_b4b27_row5_col4, #T_b4b27_row6_col0, #T_b4b27_row6_col1, #T_b4b27_row6_col5, #T_b4b27_row6_col6, #T_b4b27_row7_col0, #T_b4b27_row8_col0, #T_b4b27_row8_col1, #T_b4b27_row8_col2, #T_b4b27_row8_col5, #T_b4b27_row8_col6, #T_b4b27_row8_col7, #T_b4b27_row9_col0, #T_b4b27_row10_col0, #T_b4b27_row10_col1, #T_b4b27_row10_col5, #T_b4b27_row10_col6, #T_b4b27_row10_col7, #T_b4b27_row11_col0, #T_b4b27_row12_col0, #T_b4b27_row12_col1, #T_b4b27_row12_col5, #T_b4b27_row12_col6, #T_b4b27_row12_col7, #T_b4b27_row13_col0, #T_b4b27_row14_col0, #T_b4b27_row14_col1, #T_b4b27_row14_col5, #T_b4b27_row14_col6, #T_b4b27_row15_col0, #T_b4b27_row15_col1, #T_b4b27_row15_col5, #T_b4b27_row16_col0, #T_b4b27_row16_col1, #T_b4b27_row16_col5, #T_b4b27_row16_col6, #T_b4b27_row17_col0, #T_b4b27_row17_col1, #T_b4b27_row17_col5, #T_b4b27_row18_col0, #T_b4b27_row18_col1, #T_b4b27_row18_col5, #T_b4b27_row18_col6, #T_b4b27_row19_col0, #T_b4b27_row19_col1, #T_b4b27_row19_col5, #T_b4b27_row19_col6, #T_b4b27_row20_col0, #T_b4b27_row20_col1, #T_b4b27_row20_col5, #T_b4b27_row21_col0, #T_b4b27_row21_col1, #T_b4b27_row21_col5, #T_b4b27_row21_col6, #T_b4b27_row22_col0, #T_b4b27_row23_col0, #T_b4b27_row23_col1, #T_b4b27_row23_col5, #T_b4b27_row23_col6, #T_b4b27_row24_col0, #T_b4b27_row25_col0, #T_b4b27_row25_col2, #T_b4b27_row25_col5, #T_b4b27_row25_col6, #T_b4b27_row25_col7, #T_b4b27_row26_col0, #T_b4b27_row26_col1, #T_b4b27_row27_col0, #T_b4b27_row27_col1, #T_b4b27_row27_col2, #T_b4b27_row27_col5, #T_b4b27_row27_col6, #T_b4b27_row27_col7, #T_b4b27_row28_col0, #T_b4b27_row29_col0, #T_b4b27_row29_col1, #T_b4b27_row29_col5, #T_b4b27_row29_col6, #T_b4b27_row29_col7, #T_b4b27_row30_col0, #T_b4b27_row30_col1, #T_b4b27_row30_col5, #T_b4b27_row30_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b4b27_row0_col1 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_b4b27_row0_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_b4b27_row0_col3 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_b4b27_row0_col4, #T_b4b27_row13_col7 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_b4b27_row0_col5, #T_b4b27_row0_col7, #T_b4b27_row5_col2, #T_b4b27_row9_col3, #T_b4b27_row9_col4, #T_b4b27_row13_col1, #T_b4b27_row22_col4, #T_b4b27_row24_col1, #T_b4b27_row24_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b4b27_row0_col6, #T_b4b27_row24_col5 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_b4b27_row1_col1, #T_b4b27_row1_col5, #T_b4b27_row1_col7, #T_b4b27_row4_col6, #T_b4b27_row5_col1, #T_b4b27_row7_col1, #T_b4b27_row7_col5, #T_b4b27_row14_col7, #T_b4b27_row15_col6, #T_b4b27_row17_col6, #T_b4b27_row21_col7, #T_b4b27_row23_col7, #T_b4b27_row25_col1, #T_b4b27_row26_col5, #T_b4b27_row26_col6, #T_b4b27_row28_col1, #T_b4b27_row28_col5, #T_b4b27_row30_col2, #T_b4b27_row30_col7 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_b4b27_row1_col2, #T_b4b27_row2_col6, #T_b4b27_row7_col6, #T_b4b27_row10_col2, #T_b4b27_row12_col2, #T_b4b27_row16_col7, #T_b4b27_row21_col2, #T_b4b27_row28_col6, #T_b4b27_row29_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_b4b27_row1_col3, #T_b4b27_row25_col3, #T_b4b27_row27_col3 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_b4b27_row1_col4, #T_b4b27_row14_col4, #T_b4b27_row25_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_b4b27_row2_col2 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_b4b27_row2_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_b4b27_row2_col4, #T_b4b27_row7_col4, #T_b4b27_row17_col7, #T_b4b27_row19_col7, #T_b4b27_row26_col7 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_b4b27_row2_col7, #T_b4b27_row4_col7, #T_b4b27_row8_col4, #T_b4b27_row10_col4, #T_b4b27_row11_col6, #T_b4b27_row12_col4, #T_b4b27_row16_col4, #T_b4b27_row21_col4, #T_b4b27_row23_col4, #T_b4b27_row26_col4, #T_b4b27_row27_col4, #T_b4b27_row28_col7, #T_b4b27_row29_col4, #T_b4b27_row30_col4 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_b4b27_row3_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_b4b27_row3_col3 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_b4b27_row3_col4, #T_b4b27_row17_col4, #T_b4b27_row20_col7 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_b4b27_row3_col6, #T_b4b27_row5_col5, #T_b4b27_row20_col6 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_b4b27_row3_col7, #T_b4b27_row5_col6, #T_b4b27_row11_col4, #T_b4b27_row11_col7, #T_b4b27_row16_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_b4b27_row4_col2, #T_b4b27_row21_col3, #T_b4b27_row29_col3 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_b4b27_row4_col3, #T_b4b27_row20_col3 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_b4b27_row4_col4, #T_b4b27_row6_col7, #T_b4b27_row14_col2, #T_b4b27_row15_col7, #T_b4b27_row18_col7, #T_b4b27_row23_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_b4b27_row5_col7 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_b4b27_row6_col2, #T_b4b27_row19_col2 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_b4b27_row6_col3, #T_b4b27_row15_col3, #T_b4b27_row26_col3, #T_b4b27_row28_col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_b4b27_row6_col4, #T_b4b27_row11_col1, #T_b4b27_row11_col5, #T_b4b27_row15_col4, #T_b4b27_row18_col4, #T_b4b27_row19_col4, #T_b4b27_row20_col4, #T_b4b27_row28_col4 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_b4b27_row7_col2 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_b4b27_row7_col3 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_b4b27_row7_col7 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_b4b27_row8_col3, #T_b4b27_row10_col3, #T_b4b27_row12_col3, #T_b4b27_row30_col3 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_b4b27_row9_col1, #T_b4b27_row13_col3 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_b4b27_row9_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_b4b27_row9_col5, #T_b4b27_row13_col6, #T_b4b27_row24_col4 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_b4b27_row9_col6 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_b4b27_row9_col7 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_b4b27_row11_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_b4b27_row11_col3 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_b4b27_row13_col2 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_b4b27_row13_col4, #T_b4b27_row24_col7 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_b4b27_row13_col5 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_b4b27_row14_col3, #T_b4b27_row23_col3 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_b4b27_row15_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_b4b27_row16_col3, #T_b4b27_row17_col3, #T_b4b27_row18_col3, #T_b4b27_row28_col3 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_b4b27_row17_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_b4b27_row18_col2 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_b4b27_row19_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_b4b27_row20_col2 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_b4b27_row22_col1, #T_b4b27_row22_col5 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_b4b27_row22_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_b4b27_row22_col3 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_b4b27_row22_col6 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_b4b27_row22_col7 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_b4b27_row24_col2 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_b4b27_row24_col3 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_b4b27_row26_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# </style>
# <table id="T_b4b27">
#   <thead>
#     <tr>

# %%
col_total = df.filter(like="종합지수").columns
col_total
# Out:
# Index(['선행종합지수(2020=100)', '선행종합지수 전월비(%)', '동행종합지수(2020=100)',
#        '동행종합지수 전월비(%)', '후행종합지수(2020=100)', '후행종합지수 전월비(%)'],
#       dtype='str')

# %%
df.filter(like="종합지수").plot(subplots=True, figsize=(12, 8));
