# %% [markdown]
# # [코로나 전후 항공사별 항공수요 분석](https://www.youtube.com/watch?v=bCCWwmaSJ0E&list=PLaTc2c6yEwmqrXsGvpB3vK_nAzPEzr-ib&index=2)

# %% [markdown]
# ## [국가통계포털](https://www.kosis.kr/index/index.do)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## [항공사별 통계 다운로드](https://kosis.kr/statHtml/statHtml.do?orgId=381&tblId=DT_920005_B008&conn_path=I2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd #데이터 분석용
from glob import glob #os(오퍼레이트 시스템 즉 윈도우나 리눅스같은거 얘기함.)에 있는 파일 또는 폴더를 조회

file_names = glob("data/*.csv") #*은 전체를 가지고오라는 말임. data폴더의 전체 csv파일가지고 오라는말임.(총 두개의 csv)
file_names
# Out:
# ['data\\kosis-airline-company.csv', 'data\\kosis-economic.csv']

# %%
df_comp = pd.read_csv(file_names[0]) #우리에게 필요한건 첫번째 데이터파일이니까 이렇게 읽으면됨.
df_comp.info() #파일에 표현되어있는 정보를 알려줘.즉 컬럼과 로우에대한 정보를 알려주는거임.컬럼은 데이터를 뜻하는거고, 로우는 데이터의 양을 뜻함.
#rangeIndex는 로우데이터임. 즉 전체데이터임. 전체데이터가 적으면 적을수록 모델학습시 학습을 시킬수없고, 데이터 분석때도 분석을 할수가없음. 즉 전체데이터가 몇개인지도 중요한정보임.
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3132 entries, 0 to 3131
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시점        3132 non-null   float64
#  1   항공사별(1)   3132 non-null   str
#  2   도착출발별(1)  3132 non-null   str
#  3   운항 (편)    3132 non-null   int64
#  4   여객 (명)    3132 non-null   int64
#  5   화물 (톤)    3132 non-null   int64
# dtypes: float64(1), int64(3), str(2)
# memory usage: 146.9 KB

# %%
df_comp = pd.read_csv(file_names[0], dtype={"시점": "object"}) #우린 시점을 보면 2017.01이렇게 읽고 있는데 컴퓨터는 그냥 float(소수점)로 해석을 하고있음. 이렇게 두면안되잖아?제대로 읽도록 해줘야지.시점을 object으로 표현해줘라는뜻임
df_comp.head()
# Out:
#         시점 항공사별(1) 도착출발별(1)  운항 (편)   여객 (명)  화물 (톤)
# 0  2017.01  아시아나항공        계   12278  2150562   83765
# 1  2017.01  아시아나항공       도착    6141  1071932   41237
# 2  2017.01  아시아나항공       출발    6137  1078630   42528
# 3  2017.01    에어부산        계    5551   917653   10293
# 4  2017.01    에어부산       도착    2777   458649    6799

# %%
df_comp.info() #시점이 문자열로 바뀐거 볼수있지? object가 뭐지?
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3132 entries, 0 to 3131
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시점        3132 non-null   object
#  1   항공사별(1)   3132 non-null   str
#  2   도착출발별(1)  3132 non-null   str
#  3   운항 (편)    3132 non-null   int64
#  4   여객 (명)    3132 non-null   int64
#  5   화물 (톤)    3132 non-null   int64
# dtypes: int64(3), object(1), str(2)
# memory usage: 146.9+ KB

# %% [markdown]
# ## 데이터 분석

# %%
import matplotlib.pyplot as plt #그래프 생성/수정 할때 사용하는 모듈/라이브러리
import koreanize_matplotlib #한국어 깨짐 방지

# %%
df_com_sum = df_comp[df_comp['도착출발별(1)'] == '계']
df_com_arrive = df_comp[df_comp['도착출발별(1)'] == '도착']
df_com_depart = df_comp[df_comp['도착출발별(1)'] == '출발']

df_com_sum.shape, df_com_arrive.shape, df_com_depart.shape
# Out:
# ((1044, 6), (1044, 6), (1044, 6))

# %% [markdown]
# ### 항공사별로 연간 평균 여객 수 계산

# %%
# 항공사별로 연간 평균 여객 수 계산
average_passengers_by_airline = df_com_sum.groupby("항공사별(1)")["여객 (명)"].mean()

# 그래프로 표시
plt.figure(figsize=(12, 3))
average_passengers_by_airline.plot(kind="bar", color="skyblue")
plt.title("항공사별 연간 평균 여객 수")
plt.xlabel("항공사")
plt.ylabel("평균 여객 수")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 연간 운항 및 여객 증가율 계산:
# - 연간 운항 편수 및 여객 수의 증가율을 계산하여 항공사별로 비교합니다.

# %%
# 연간 운항 편수 증가율 계산
df_com_sum["운항 (편)_증가율"] = df_com_sum.groupby("항공사별(1)")["운항 (편)"].pct_change() * 100

# 연간 여객 수 증가율 계산
df_com_sum["여객 (명)_증가율"] = df_com_sum.groupby("항공사별(1)")["여객 (명)"].pct_change() * 100
df_com_sum.head()
# Out:
#          시점 항공사별(1) 도착출발별(1)  운항 (편)   여객 (명)  화물 (톤)  운항 (편)_증가율  여객 (명)_증가율
# 0   2017.01  아시아나항공        계   12278  2150562   83765         NaN         NaN
# 3   2017.01    에어부산        계    5551   917653   10293         NaN         NaN
# 6   2017.01    에어인천        계      86        0     597         NaN         NaN
# 9   2017.01    에어서울        계     415    61421     604         NaN         NaN
# 12  2017.01    제주항공        계    6662  1169280    8535         NaN         NaN

# %%
df_com_sum.tail()
# Out:
#            시점  항공사별(1) 도착출발별(1)  운항 (편)   여객 (명)  화물 (톤)  운항 (편)_증가율  \
# 3117  2024.11    티웨이항공        계    6692  1228161   10359   -3.238866
# 3120  2024.11    이스타항공        계    3515   613644    3429   -6.887417
# 3123  2024.11  에어로케이항공        계     704   114342     787  -22.891566
# 3126  2024.11   에어프레미아        계     229    58199    3143   -5.371901
# 3129  2024.11      외항사        계   14380  2247274  118616   -7.536008
#
#       여객 (명)_증가율
# 3117    1.158225
# 3120   -4.351716
# 3123  -21.709837
# 3126  -10.272579
# 3129   -7.110608

# %% [markdown]
# ### 도착/출발별로 연간 운항 및 여객 분석:
# - 도착과 출발별로 연간 운항 편수 및 여객 수를 분석합니다

# %%
# 도착별 연간 운항 편수 및 여객 수 분석
arrival_stats = df_com_arrive.groupby("시점")[["운항 (편)", "여객 (명)"]].sum()

arrival_stats.head()
# Out:
#          운항 (편)   여객 (명)
# 시점
# 2017.01   35679  6020504
# 2017.02   32213  5629399
# 2017.03   35118  5606531
# 2017.04   34226  5777657
# 2017.05   35760  5969435

# %%
# 출발별 연간 운항 편수 및 여객 수 분석
departure_stats = df_com_depart.groupby("시점")[["운항 (편)", "여객 (명)"]].sum()

departure_stats.head()
# Out:
#          운항 (편)   여객 (명)
# 시점
# 2017.01   35652  6098020
# 2017.02   32219  5603581
# 2017.03   35122  5471766
# 2017.04   34244  5917312
# 2017.05   35751  5841676

# %%
departure_stats.plot(secondary_y="여객 (명)")
# Out:
# <Axes: xlabel='시점'>

# %% [markdown]
# ### 시간에 따른 화물 운송량 시각화:
# - 시간에 따른 화물 운송량의 추이를 시각화합니다.

# %%
df_com_sum.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1044 entries, 0 to 3129
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   시점          1044 non-null   object
#  1   항공사별(1)     1044 non-null   str
#  2   도착출발별(1)    1044 non-null   str
#  3   운항 (편)      1044 non-null   int64
#  4   여객 (명)      1044 non-null   int64
#  5   화물 (톤)      1044 non-null   int64
#  6   운항 (편)_증가율  1031 non-null   float64
#  7   여객 (명)_증가율  936 non-null    float64
# dtypes: float64(2), int64(3), object(1), str(2)
# memory usage: 65.4+ KB

# %%
df_com_sum.head()
# Out:
#          시점 항공사별(1) 도착출발별(1)  운항 (편)   여객 (명)  화물 (톤)  운항 (편)_증가율  여객 (명)_증가율
# 0   2017.01  아시아나항공        계   12278  2150562   83765         NaN         NaN
# 3   2017.01    에어부산        계    5551   917653   10293         NaN         NaN
# 6   2017.01    에어인천        계      86        0     597         NaN         NaN
# 9   2017.01    에어서울        계     415    61421     604         NaN         NaN
# 12  2017.01    제주항공        계    6662  1169280    8535         NaN         NaN

# %%
# 시간에 따른 화물 운송량 시각화
df_com_sum["시점"] = pd.to_datetime(df_com_sum["시점"])  # 날짜 형식으로 변환
df_com_sum.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1044 entries, 0 to 3129
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   시점          1044 non-null   datetime64[us]
#  1   항공사별(1)     1044 non-null   str
#  2   도착출발별(1)    1044 non-null   str
#  3   운항 (편)      1044 non-null   int64
#  4   여객 (명)      1044 non-null   int64
#  5   화물 (톤)      1044 non-null   int64
#  6   운항 (편)_증가율  1031 non-null   float64
#  7   여객 (명)_증가율  936 non-null    float64
# dtypes: datetime64[us](1), float64(2), int64(3), str(2)
# memory usage: 65.4 KB
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_1192\3103388101.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_com_sum["시점"] = pd.to_datetime(df_com_sum["시점"])  # 날짜 형식으로 변환

# %%
df_com_sum["년"] = df_com_sum["시점"].dt.year
df_com_sum["월"] = df_com_sum["시점"].dt.month
# df_com_sum["일"] = df_com_sum["시점"].dt.day
# df_com_sum["요일"] = df_com_sum["시점"].dt.dayofweek # (월 = 0)

# %%
df_com_sum.tail()
# Out:
#              시점  항공사별(1) 도착출발별(1)  운항 (편)   여객 (명)  화물 (톤)  운항 (편)_증가율  \
# 3117 2024-11-01    티웨이항공        계    6692  1228161   10359   -3.238866
# 3120 2024-11-01    이스타항공        계    3515   613644    3429   -6.887417
# 3123 2024-11-01  에어로케이항공        계     704   114342     787  -22.891566
# 3126 2024-11-01   에어프레미아        계     229    58199    3143   -5.371901
# 3129 2024-11-01      외항사        계   14380  2247274  118616   -7.536008
#
#       여객 (명)_증가율     년   월
# 3117    1.158225  2024  11
# 3120   -4.351716  2024  11
# 3123  -21.709837  2024  11
# 3126  -10.272579  2024  11
# 3129   -7.110608  2024  11

# %%
plt.figure(figsize=(12, 6)) # 도화지 크기 (12, 6)

plt.plot( # 선형 그래프
    # df_com_sum -> 모든 항공 데이터
    # df_com_sum[df_com_sum["항공사별(1)"] == "아시아나항공"] -> 아시아나항공 데이터
    # df_com_sum[df_com_sum["항공사별(1)"] == "아시아나항공"]["년"] -> 아시아나항공의 년도 데이터
    df_com_sum[df_com_sum["항공사별(1)"] == "아시아나항공"]["년"] # x 축 데이터
    , df_com_sum[df_com_sum["항공사별(1)"] == "아시아나항공"]["화물 (톤)"] # y 축 데이터
    , label="아시아나항공") # 선형 그래프명

plt.plot(
    df_com_sum[df_com_sum["항공사별(1)"] == "대한항공"]["년"]
    , df_com_sum[df_com_sum["항공사별(1)"] == "대한항공"]["화물 (톤)"]
    , label="대한항공")


plt.xlabel("년도")
plt.ylabel("화물 운송량 (톤)")
plt.legend()
plt.title("시간에 따른 화물 운송량 추이")
plt.show()

# %%
df_com_sum["항공사별(1)"].unique()
# Out:
# <StringArray>
# [ '아시아나항공',    '에어부산',    '에어인천',    '에어서울',    '제주항공',     '진에어',    '대한항공',
#    '티웨이항공',   '이스타항공',     '외항사',   '플라이강원', '에어로케이항공',  '에어프레미아']
# Length: 13, dtype: str

# %%
year_comp = pd.crosstab(index=df_com_sum["년"],
            columns=df_com_sum["항공사별(1)"],
            values=df_com_sum["여객 (명)"],
            aggfunc="sum").fillna(0)

year_comp.style.background_gradient(axis=None).format("{:,.0f}")
# Out:
# <style type="text/css">
# #T_bec18_row0_col0 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_bec18_row0_col1 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_bec18_row0_col2, #T_bec18_row0_col5, #T_bec18_row0_col6, #T_bec18_row0_col12, #T_bec18_row1_col2, #T_bec18_row1_col5, #T_bec18_row1_col6, #T_bec18_row1_col12, #T_bec18_row2_col2, #T_bec18_row2_col5, #T_bec18_row2_col6, #T_bec18_row2_col12, #T_bec18_row3_col2, #T_bec18_row3_col5, #T_bec18_row3_col6, #T_bec18_row4_col5, #T_bec18_row4_col8, #T_bec18_row5_col5, #T_bec18_row5_col6, #T_bec18_row5_col8, #T_bec18_row6_col5, #T_bec18_row7_col5, #T_bec18_row7_col12 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bec18_row0_col3, #T_bec18_row5_col11 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_bec18_row0_col4, #T_bec18_row5_col2, #T_bec18_row5_col12, #T_bec18_row7_col6 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_bec18_row0_col7 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_bec18_row0_col8 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_bec18_row0_col9 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_bec18_row0_col10, #T_bec18_row1_col10 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_bec18_row0_col11 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_bec18_row1_col0 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_bec18_row1_col1 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_bec18_row1_col3 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_bec18_row1_col4, #T_bec18_row3_col8 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_bec18_row1_col7 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_bec18_row1_col8 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_bec18_row1_col9 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_bec18_row1_col11 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_bec18_row2_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bec18_row2_col1 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_bec18_row2_col3 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_bec18_row2_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_bec18_row2_col7 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_bec18_row2_col8 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_bec18_row2_col9 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_bec18_row2_col10 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_bec18_row2_col11, #T_bec18_row3_col1 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_bec18_row3_col0, #T_bec18_row4_col10 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_bec18_row3_col3 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_bec18_row3_col4 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_bec18_row3_col7 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_bec18_row3_col9 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_bec18_row3_col10 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_bec18_row3_col11 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_bec18_row3_col12 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_bec18_row4_col0, #T_bec18_row7_col3 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_bec18_row4_col1 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_bec18_row4_col2, #T_bec18_row4_col6, #T_bec18_row4_col12, #T_bec18_row6_col12 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_bec18_row4_col3 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_bec18_row4_col4, #T_bec18_row5_col4 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_bec18_row4_col7 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_bec18_row4_col9, #T_bec18_row5_col10 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_bec18_row4_col11 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_bec18_row5_col0 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_bec18_row5_col1 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_bec18_row5_col3 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_bec18_row5_col7 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_bec18_row5_col9, #T_bec18_row6_col11 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_bec18_row6_col0 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_bec18_row6_col1 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_bec18_row6_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_bec18_row6_col3 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_bec18_row6_col4 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_bec18_row6_col6 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_bec18_row6_col7 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_bec18_row6_col8 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_bec18_row6_col9 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_bec18_row6_col10 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_bec18_row7_col0 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_bec18_row7_col1 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_bec18_row7_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_bec18_row7_col4 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_bec18_row7_col7 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_bec18_row7_col8 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_bec18_row7_col9 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_bec18_row7_col10 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_bec18_row7_col11 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# </style>
# <table id="T_bec18">
#   <thead>
#     <tr>
#       <th class="index_name level0" >항공사별(1)</th>
#       <th id="T_bec18_level0_col0" class="col_heading level0 col0" >대한항공</th>
#       <th id="T_bec18_level0_col1" class="col_heading level0 col1" >아시아나항공</th>
#       <th id="T_bec18_level0_col2" class="col_heading level0 col2" >에어로케이항공</th>
#       <th id="T_bec18_level0_col3" class="col_heading level0 col3" >에어부산</th>
#       <th id="T_bec18_level0_col4" class="col_heading level0 col4" >에어서울</th>
#       <th id="T_bec18_level0_col5" class="col_heading level0 col5" >에어인천</th>
#       <th id="T_bec18_level0_col6" class="col_heading level0 col6" >에어프레미아</th>
#       <th id="T_bec18_level0_col7" class="col_heading level0 col7" >외항사</th>
#       <th id="T_bec18_level0_col8" class="col_heading level0 col8" >이스타항공</th>
#       <th id="T_bec18_level0_col9" class="col_heading level0 col9" >제주항공</th>
#       <th id="T_bec18_level0_col10" class="col_heading level0 col10" >진에어</th>
#       <th id="T_bec18_level0_col11" class="col_heading level0 col11" >티웨이항공</th>
#       <th id="T_bec18_level0_col12" class="col_heading level0 col12" >플라이강원</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >년</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bec18_level0_row0" class="row_heading level0 row0" >2017</th>
#       <td id="T_bec18_row0_col0" class="data row0 col0" >35,287,835</td>
#       <td id="T_bec18_row0_col1" class="data row0 col1" >25,605,946</td>
#       <td id="T_bec18_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_bec18_row0_col3" class="data row0 col3" >11,363,466</td>
#       <td id="T_bec18_row0_col4" class="data row0 col4" >826,908</td>
#       <td id="T_bec18_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_bec18_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_bec18_row0_col7" class="data row0 col7" >24,513,986</td>
#       <td id="T_bec18_row0_col8" class="data row0 col8" >8,633,452</td>
#       <td id="T_bec18_row0_col9" class=

# %%
year_comp[['제주항공', '진에어', '에어부산', '이스타항공', '티웨이항공',
       '에어인천', '에어서울', '플라이강원', '에어로케이항공']].plot(
           figsize=(12, 3), title="저가항공 연도별 여객 수")
# Out:
# <Axes: title={'center': '저가항공 연도별 여객 수'}, xlabel='년'>

# %%
year_comp = pd.crosstab(index=df_com_sum["년"],
            columns=df_com_sum["항공사별(1)"],
            values=df_com_sum["운항 (편)"],
            aggfunc="sum").fillna(0)

year_comp.style.background_gradient(axis=None, cmap="Greens").format("{:,.0f}")
# Out:
# <style type="text/css">
# #T_1b339_row0_col0, #T_1b339_row1_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_1b339_row0_col1 {
#   background-color: #369f54;
#   color: #f1f1f1;
# }
# #T_1b339_row0_col2, #T_1b339_row0_col6, #T_1b339_row0_col12, #T_1b339_row1_col2, #T_1b339_row1_col6, #T_1b339_row1_col12, #T_1b339_row2_col2, #T_1b339_row2_col6, #T_1b339_row2_col12, #T_1b339_row3_col2, #T_1b339_row3_col6, #T_1b339_row4_col6, #T_1b339_row4_col8, #T_1b339_row5_col6, #T_1b339_row5_col8, #T_1b339_row7_col12 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_1b339_row0_col3 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_1b339_row0_col4, #T_1b339_row5_col12 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_1b339_row0_col5, #T_1b339_row1_col5, #T_1b339_row2_col5, #T_1b339_row3_col5, #T_1b339_row4_col5, #T_1b339_row6_col6, #T_1b339_row6_col12 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_1b339_row0_col7 {
#   background-color: #29914a;
#   color: #f1f1f1;
# }
# #T_1b339_row0_col8 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_1b339_row0_col9 {
#   background-color: #98d594;
#   color: #000000;
# }
# #T_1b339_row0_col10, #T_1b339_row3_col9, #T_1b339_row6_col3 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_1b339_row0_col11, #T_1b339_row2_col8 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_1b339_row1_col1 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_1b339_row1_col3 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_1b339_row1_col4 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_1b339_row1_col7 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_1b339_row1_col8 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_1b339_row1_col9 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_1b339_row1_col10 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_1b339_row1_col11, #T_1b339_row4_col7 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_1b339_row2_col0 {
#   background-color: #00471c;
#   color: #f1f1f1;
# }
# #T_1b339_row2_col1 {
#   background-color: #3ca559;
#   color: #f1f1f1;
# }
# #T_1b339_row2_col3, #T_1b339_row4_col10 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_1b339_row2_col4 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_1b339_row2_col7 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_1b339_row2_col9 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_1b339_row2_col10 {
#   background-color: #b7e2b1;
#   color: #000000;
# }
# #T_1b339_row2_col11 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_1b339_row3_col0 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_1b339_row3_col1, #T_1b339_row5_col9 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_1b339_row3_col3 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_1b339_row3_col4 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_1b339_row3_col7 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_1b339_row3_col8, #T_1b339_row7_col2 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_1b339_row3_col10 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_1b339_row3_col11 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_1b339_row3_col12, #T_1b339_row4_col2, #T_1b339_row4_col12, #T_1b339_row5_col5, #T_1b339_row7_col5, #T_1b339_row7_col6 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_1b339_row4_col0 {
#   background-color: #66bd6f;
#   color: #f1f1f1;
# }
# #T_1b339_row4_col1, #T_1b339_row6_col11, #T_1b339_row7_col10 {
#   background-color: #a2d99c;
#   color: #000000;
# }
# #T_1b339_row4_col3 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_1b339_row4_col4 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_1b339_row4_col9 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_1b339_row4_col11, #T_1b339_row5_col11 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_1b339_row5_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_1b339_row5_col1 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_1b339_row5_col2 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_1b339_row5_col3 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_1b339_row5_col4 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_1b339_row5_col7 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_1b339_row5_col10 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_1b339_row6_col0 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_1b339_row6_col1 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_1b339_row6_col2 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_1b339_row6_col4 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_1b339_row6_col5 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_1b339_row6_col7 {
#   background-color: #3aa357;
#   color: #f1f1f1;
# }
# #T_1b339_row6_col8 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_1b339_row6_col9 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_1b339_row6_col10 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_1b339_row7_col0 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_1b339_row7_col1 {
#   background-color: #7ac77b;
#   color: #000000;
# }
# #T_1b339_row7_col3 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_1b339_row7_col4 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_1b339_row7_col7 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_1b339_row7_col8 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_1b339_row7_col9 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_1b339_row7_col11 {
#   background-color: #abdda5;
#   color: #000000;
# }
# </style>
# <table id="T_1b339">
#   <thead>
#     <tr>
#       <th class="index_name level0" >항공사별(1)</th>
#       <th id="T_1b339_level0_col0" class="col_heading level0 col0" >대한항공</th>
#       <th id="T_1b339_level0_col1" class="col_heading level0 col1" >아시아나항공</th>
#       <th id="T_1b339_level0_col2" class="col_heading level0 col2" >에어로케이항공</th>
#       <th id="T_1b339_level0_col3" class="col_heading level0 col3" >에어부산</th>
#       <th id="T_1b339_level0_col4" class="col_heading level0 col4" >에어서울</th>
#       <th id="T_1b339_level0_col5" class="col_heading level0 col5" >에어인천</th>
#       <th id="T_1b339_level0_col6" class="col_heading level0 col6" >에어프레미아</th>
#       <th id="T_1b339_level0_col7" class="col_heading level0 col7" >외항사</th>
#       <th id="T_1b339_level0_col8" class="col_heading level0 col8" >이스타항공</th>
#       <th id="T_1b339_level0_col9" class="col_heading level0 col9" >제주항공</th>
#       <th id="T_1b339_level0_col10" class="col_heading level0 col10" >진에어</th>
#       <th id="T_1b339_level0_col11" class="col_heading level0 col11" >티웨이항공</th>
#       <th id="T_1b339_level0_col12" class="col_heading level0 col12" >플라이강원</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >년</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b339_level0_row0" class="row_heading level0 row0" >2017</th>
#       <td id="T_1b339_row0_col0" class="data row0 col0" >216,078</td>
#       <td id="T_1b339_row0_col1" class="data row0 col1" >144,611</td>
#       <td id="T_1b339_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_1b339_row0_col3" class="data row0 col3" >69,098</td>
#       <td id="T_1b339_row0_col4" class="data row0 col4" >5,837</td>
#       <td id="T_1b339_row0_col5" class="data row0 col5" >942</td>
#       <td id="T_1b339_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_1b339_row0_col7" class="data row0 col7" >156,448</td>
#       <td id="T_1b339_row0_col8" class="data row0 col8" >52,594</td>
#       <td id="T_1b339_row0_col9" class="data row0 col9" >86,379</td>
#       <td id="T_1b339_row0_col10" cl

# %%
year_comp[['제주항공', '진에어', '에어부산', '이스타항공', '티웨이항공',
       '에어인천', '에어서울', '플라이강원', '에어로케이항공']].plot(
           figsize=(12, 3), title="저가항공 연도별 운항 수")
# Out:
# <Axes: title={'center': '저가항공 연도별 운항 수'}, xlabel='년'>

# %%
year_comp = pd.crosstab(index=df_com_sum["년"],
            columns=df_com_sum["항공사별(1)"],
            values=df_com_sum["화물 (톤)"],
            aggfunc="sum").fillna(0)

year_comp.style.background_gradient(axis=None, cmap="Oranges").format("{:,.0f}")
# Out:
# <style type="text/css">
# #T_1cd79_row0_col0 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_1cd79_row0_col1 {
#   background-color: #fa8331;
#   color: #f1f1f1;
# }
# #T_1cd79_row0_col2, #T_1cd79_row0_col5, #T_1cd79_row0_col6, #T_1cd79_row0_col12, #T_1cd79_row1_col2, #T_1cd79_row1_col6, #T_1cd79_row1_col12, #T_1cd79_row2_col2, #T_1cd79_row2_col6, #T_1cd79_row2_col12, #T_1cd79_row3_col2, #T_1cd79_row3_col6, #T_1cd79_row3_col12, #T_1cd79_row4_col2, #T_1cd79_row4_col6, #T_1cd79_row4_col8, #T_1cd79_row4_col12, #T_1cd79_row5_col2, #T_1cd79_row5_col8, #T_1cd79_row5_col12, #T_1cd79_row6_col2, #T_1cd79_row6_col12, #T_1cd79_row7_col12 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_1cd79_row0_col3 {
#   background-color: #ffefe0;
#   color: #000000;
# }
# #T_1cd79_row0_col4, #T_1cd79_row3_col4, #T_1cd79_row3_col5, #T_1cd79_row3_col8, #T_1cd79_row4_col4, #T_1cd79_row5_col4, #T_1cd79_row5_col6, #T_1cd79_row7_col2 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_1cd79_row0_col7 {
#   background-color: #e5590a;
#   color: #f1f1f1;
# }
# #T_1cd79_row0_col8, #T_1cd79_row3_col9, #T_1cd79_row3_col10, #T_1cd79_row4_col9, #T_1cd79_row4_col11 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_1cd79_row0_col9, #T_1cd79_row2_col10, #T_1cd79_row6_col11, #T_1cd79_row7_col11 {
#   background-color: #ffeede;
#   color: #000000;
# }
# #T_1cd79_row0_col10, #T_1cd79_row2_col9 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_1cd79_row0_col11, #T_1cd79_row1_col8, #T_1cd79_row2_col8, #T_1cd79_row4_col10, #T_1cd79_row5_col3 {
#   background-color: #fff2e5;
#   color: #000000;
# }
# #T_1cd79_row1_col0 {
#   background-color: #882a04;
#   color: #f1f1f1;
# }
# #T_1cd79_row1_col1 {
#   background-color: #f87d29;
#   color: #f1f1f1;
# }
# #T_1cd79_row1_col3 {
#   background-color: #fff0e1;
#   color: #000000;
# }
# #T_1cd79_row1_col4, #T_1cd79_row1_col5, #T_1cd79_row2_col4, #T_1cd79_row2_col5, #T_1cd79_row6_col4, #T_1cd79_row6_col8, #T_1cd79_row7_col4 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_1cd79_row1_col7 {
#   background-color: #dd4d04;
#   color: #f1f1f1;
# }
# #T_1cd79_row1_col9, #T_1cd79_row1_col10, #T_1cd79_row6_col10, #T_1cd79_row7_col10 {
#   background-color: #ffeedd;
#   color: #000000;
# }
# #T_1cd79_row1_col11, #T_1cd79_row5_col11 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# #T_1cd79_row2_col0 {
#   background-color: #9e3303;
#   color: #f1f1f1;
# }
# #T_1cd79_row2_col1 {
#   background-color: #fb8634;
#   color: #f1f1f1;
# }
# #T_1cd79_row2_col3, #T_1cd79_row5_col9, #T_1cd79_row6_col3 {
#   background-color: #fff0e2;
#   color: #000000;
# }
# #T_1cd79_row2_col7 {
#   background-color: #db4a02;
#   color: #f1f1f1;
# }
# #T_1cd79_row2_col11, #T_1cd79_row5_col10, #T_1cd79_row7_col3 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# #T_1cd79_row3_col0 {
#   background-color: #c54102;
#   color: #f1f1f1;
# }
# #T_1cd79_row3_col1 {
#   background-color: #fd9e54;
#   color: #000000;
# }
# #T_1cd79_row3_col3, #T_1cd79_row3_col11, #T_1cd79_row4_col3, #T_1cd79_row5_col5, #T_1cd79_row6_col5 {
#   background-color: #fff3e6;
#   color: #000000;
# }
# #T_1cd79_row3_col7 {
#   background-color: #fd9243;
#   color: #000000;
# }
# #T_1cd79_row4_col0 {
#   background-color: #963003;
#   color: #f1f1f1;
# }
# #T_1cd79_row4_col1, #T_1cd79_row6_col1 {
#   background-color: #fd9f56;
#   color: #000000;
# }
# #T_1cd79_row4_col5 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_1cd79_row4_col7, #T_1cd79_row5_col7 {
#   background-color: #f77b28;
#   color: #f1f1f1;
# }
# #T_1cd79_row5_col0 {
#   background-color: #ab3803;
#   color: #f1f1f1;
# }
# #T_1cd79_row5_col1 {
#   background-color: #fda45d;
#   color: #000000;
# }
# #T_1cd79_row6_col0 {
#   background-color: #ae3903;
#   color: #f1f1f1;
# }
# #T_1cd79_row6_col6, #T_1cd79_row7_col5, #T_1cd79_row7_col6, #T_1cd79_row7_col8 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_1cd79_row6_col7 {
#   background-color: #ee6511;
#   color: #f1f1f1;
# }
# #T_1cd79_row6_col9, #T_1cd79_row7_col9 {
#   background-color: #feecda;
#   color: #000000;
# }
# #T_1cd79_row7_col0 {
#   background-color: #b03903;
#   color: #f1f1f1;
# }
# #T_1cd79_row7_col1 {
#   background-color: #fda35c;
#   color: #000000;
# }
# #T_1cd79_row7_col7 {
#   background-color: #eb600e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1cd79">
#   <thead>
#     <tr>
#       <th class="index_name level0" >항공사별(1)</th>
#       <th id="T_1cd79_level0_col0" class="col_heading level0 col0" >대한항공</th>
#       <th id="T_1cd79_level0_col1" class="col_heading level0 col1" >아시아나항공</th>
#       <th id="T_1cd79_level0_col2" class="col_heading level0 col2" >에어로케이항공</th>
#       <th id="T_1cd79_level0_col3" class="col_heading level0 col3" >에어부산</th>
#       <th id="T_1cd79_level0_col4" class="col_heading level0 col4" >에어서울</th>
#       <th id="T_1cd79_level0_col5" class="col_heading level0 col5" >에어인천</th>
#       <th id="T_1cd79_level0_col6" class="col_heading level0 col6" >에어프레미아</th>
#       <th id="T_1cd79_level0_col7" class="col_heading level0 col7" >외항사</th>
#       <th id="T_1cd79_level0_col8" class="col_heading level0 col8" >이스타항공</th>
#       <th id="T_1cd79_level0_col9" class="col_heading level0 col9" >제주항공</th>
#       <th id="T_1cd79_level0_col10" class="col_heading level0 col10" >진에어</th>
#       <th id="T_1cd79_level0_col11" class="col_heading level0 col11" >티웨이항공</th>
#       <th id="T_1cd79_level0_col12" class="col_heading level0 col12" >플라이강원</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >년</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1cd79_level0_row0" class="row_heading level0 row0" >2017</th>
#       <td id="T_1cd79_row0_col0" class="data row0 col0" >1,879,326</td>
#       <td id="T_1cd79_row0_col1" class="data row0 col1" >1,003,181</td>
#       <td id="T_1cd79_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_1cd79_row0_col3" class="data row0 col3" >89,047</td>
#       <td id="T_1cd79_row0_col4" class="data row0 col4" >8,260</td>
#       <td id="T_1cd79_row0_col5" class="data row0 col5" >6,676</td>
#       <td id="T_1cd79_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_1cd79_row0_col7" class="data row0 col7" >1,289,794</td>
#       <td id="T_1cd79_row0_col8" class="data row0 col8" >50,148</td>
#       <td id="T_1cd79_row0_col9" class="data row0 col9" >104,760</td>
#       <td id="T_1cd79_row0_col10" class="data row0 col10" >121,992</td>
#       <td id="T_1cd79_row0_col11" class="data row0 col11" >58,585</td>
#       <td id="T_1cd79_row0_col12" class="data row0 col12" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1cd79_level0_row1" class="row_heading level0 row1" >2018</th>
#       <td id="T_1cd79_row1_col0" class="data row1 col0" >1,825,571</td>
#       <td id="T_1cd79_row1_col1" class="data row1 col1" >1,047,604</td>
#       <td id="T_1cd79_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_1cd79_row1_col3" class="data row1 col3" >84,674</td>
#       <td id="T_1cd79_row1_col4" class="data row1 col4" >15,693</td>
#       <td id="T_1cd79_row1_col5" class="data row1 col5" >18,246</td>
#       <td id="T_1cd79_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_1cd79_row1_col7" class="data row1 col7" >1,372,050</td>
#       <td id="T_1cd79_row1_col8" class="data row1 col8" >56,745</td>
#       <td id="T_1cd79_row1_col9" class="data row1 col9" >114,660</td>
#       <td id="T_1cd79_row1_col10" class="data row1 col10" >115,310</td>
#       <td id="T_1cd79_row1_col11" class="data row1 col11" >64,636</td>
#       <td id="T_1cd79_row1_col12" class="data row1 col12" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1cd79_level0_row2" class="row_heading level0 row2" >2019</th>
#       <td id="T_1cd79_row2_col0" class="data row2 col0" >1,694,441</td>

# %%
year_comp[['제주항공', '진에어', '에어부산', '이스타항공', '티웨이항공',
       '에어인천', '에어서울', '플라이강원', '에어로케이항공']].plot(
           figsize=(12, 3), title="저가항공 연도별 화물(톤) 수")
# Out:
# <Axes: title={'center': '저가항공 연도별 화물(톤) 수'}, xlabel='년'>
